# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Defining path

# %%
path = r'C:\Users\nukis\Documents\Instacart Basket Analysis'

# %% [markdown]
# #### Importing orders.csv, products.csv and departments.csv

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %% [markdown]
# # 2. Data wrangling steps

# %% [markdown]
# #### Q2. Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.

# %%
# Checking variable types
df_ords.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# Only 'eval_set' is found needed to be excluded and saved it in the new variable
df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
df_ords_2
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %% [markdown]
# #### Q3. Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the data frame.

# %%
df_ords_2.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords_2
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %% [markdown]
# #### Q4. Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.

# %%
# Counting order frequency based on time (hour)
df_ords_2['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# ##### Busiest hour is at 10:00, hour with highest number of order

# %%
df_ords_2.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %% [markdown]
# #### Q5. Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Checking departments.csv
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing df_dep and save into new variable
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Resetting df_dep_t index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Taking df_dep_t[0] as new_header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Copying 1st row onward into new variable
df_dep_t_new = df_dep_t[1:]

# %%
# Set new_header AS new header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Converting into data dictionary
df_dep_t_new_dict = df_dep_t_new.to_dict('index')

# %%
df_dep_t_new_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(df_dep_t_new_dict['4'])
# Out:
# {'department': 'produce'}

# %% [markdown]
# #### Value of 4 in the "department_id" is produce.

# %% [markdown]
# #### Q6. The sales team in your client’s organization wants to know more about "breakfast" item sales. Create a subset containing only the required information.

# %%
# This loop step is done in case we dont know where "breakfast", etc. item/department are located.
for key, value in df_dep_t_new_dict.items():
    if value['department'] == 'breakfast' or value['department'] == 'alcohol' or value['department'] == 'deli' or value['department'] == 'beverages' or value['department'] == 'meat seafood': 
        print(key, value)
# Out:
# 5 {'department': 'alcohol'}
# 7 {'department': 'beverages'}
# 12 {'department': 'meat seafood'}
# 14 {'department': 'breakfast'}
# 20 {'department': 'deli'}

# %%
# Creating subset of breakfast located in department 14
df_prods_breakfast = df_prods[df_prods['department_id'] == 14]

# %% [markdown]
# #### Q7. They’d also like to see details about customers who might be throwing dinner parties. Your task is to find all observations from the entire dataframe that include items from the following departments: "alcohol, deli, beverages, and meat/seafood". You’ll need to present this subset to your client.

# %%
# Creating combined subset of alcohol, deli, beverages, and meat/seafood located in department 5, 20, 7, 12
df_prods_dinner = df_prods[df_prods['department_id'].isin([5, 20, 7, 12])]

# %% [markdown]
# #### Q8. It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?

# %%
df_prods_dinner.shape
# Out:
# (7650, 5)

# %% [markdown]
# #### Q9. Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %%
# Extracting user_id = 1
df_user_id_1 = df_ords[df_ords['user_id'] == 1]

# %%
df_user_id_1
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# ...

# %% [markdown]
# #### Q10. You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

# %%
# Behavior can be initially analyzed by conducting descriptive statistics
df_user_id_1.describe()
# Out:
#            order_id  user_id  order_number  order_dow  order_hour_of_day  \
# count  1.100000e+01     11.0     11.000000  11.000000          11.000000
# mean   1.923450e+06      1.0      6.000000   2.636364          10.090909
# std    1.071950e+06      0.0      3.316625   1.286291           3.477198
# min    4.315340e+05      1.0      1.000000   1.000000           7.000000
# 25%    8.690170e+05      1.0      3.500000   1.500000           7.500000
# 50%    2.295261e+06      1.0      6.000000   3.000000           8.000000
# 75%    2.544846e+06      1.0      8.500000   4.000000          13.000000
# max    3.367565e+06      1.0     11.000000   4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# #### Q11. Check the organization and structure of your notebook. Be sure to include section headings and code comments

# %% [markdown]
# #### Q12. Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.

# %%
df_ords_2.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'), index = False)

# %% [markdown]
# #### Q13. Export the df_dep_t_new dataframe as “departments_wrangled.csv” in your “Prepared Data” folder so that you have a “.csv” file of your departments data in the correct format.

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'), index = False)

# %%
# Export to pkl

df_dep_t_new.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.pkl'))
